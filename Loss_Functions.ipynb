# %% [markdown]
# # Loss Functions

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.random.binomial(1, .5, 100)
yhat = np.random.rand(100)

# %%
def cross_entropy(y, yhat):
    return np.round(-1*(y*np.log(yhat) + (1-y)*np.log(1-yhat)), 5)


def mae(y, yhat):
    return np.abs(y - yhat)/len(y)


def mse(y, yhat):
    return (y - yhat)**2 / len(y)


def loss_f(f, y, yhat):
    loss_functions = {
        'cross_entropy': cross_entropy,
        'mae': mae,
        'mse': mse,
    }
    return loss_functions[f](y, yhat)

# %%
plt.figure(figsize=(21, 5))

fig, axs = plt.subplots(1, 3, figsize=(21, 7))

axs[0].plot(np.arange(0, 100), loss_f('cross_entropy', y, yhat), marker='o', color='r', label='Cross Entropy')
axs[1].plot(np.arange(0, 100), loss_f('mae', y, yhat), marker='o', color='pink', label='MAE')
axs[2].plot(np.arange(0, 100), loss_f('mse', y, yhat), marker='o', color='crimson', label='MSE')

# plt.plot(np.arange(0, 100), yhat, color='g')
# plt.bar(np.arange(0, 100), y, alpha=.7)

fig.legend(title='Loss Functions', ncol=3, loc='upper center')
